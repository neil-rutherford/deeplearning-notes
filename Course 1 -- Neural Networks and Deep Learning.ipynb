# %% [markdown]
# # What Is A Neural Network?
#
# - Inputs --> Neurons --> Outputs
# - Example inputs: Size, bedrooms, ZIP code, average income
# - Neurons: The network is allowed to decide what these are
# - Example outputs: House price
#
# ![image.png](attachment:image.png)
